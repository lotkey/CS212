# %%
import random  # random.shuffle
import string  # string.ascii_letters

# %%
def shuffle_string(s: str) -> str:
    """
    Shuffles a copy of s but shuffled
    """
    l = list(s)  # convert to list
    random.shuffle(l)  # in-place shuffle
    return "".join(l)  # convert to string and return


PLAIN_TEXT = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
CIPHER = shuffle_string(PLAIN_TEXT)  # Randomly generate a cipher
print(f"Random cipher is: {CIPHER}")
# Out:
# Random cipher is: INWSGZCOKHVPUYREXTALQJMFDB

# %%
def substitute(string_to_substitute: str, og_chars: str, new_chars: str) -> str:
    """
    Returns an encrypted string provided the string, the original characters, and a cipher.

    ## Params:
    string_to_substitute: str
    - String to encrypt with substitution method

    og_chars: str
    - The original characters

    new_chars: str
    - The cipher to substitute the original characters with
    """
    substituted = ""
    for char in string_to_substitute:
        substitute_char = og_chars[new_chars.find(char.upper())]
        # PLAIN_TEXT and CIPHER don't have lowercase characters in them, but this still adds support for them.
        if char.islower():
            substitute_char = substitute_char.lower()
        substituted += substitute_char
    return substituted


def encrypt(s: str) -> str:
    """
    Encrypts s with the randomly generated cipher
    """
    return substitute(s, PLAIN_TEXT, CIPHER)


def decrypt(s: str) -> str:
    """
    Decrypts s, assuming that it has been encrypted with the randomly generated cipher.
    """
    return substitute(s, CIPHER, PLAIN_TEXT)

# %%
def random_string() -> str:
    """
    Returns a random string of letters (lowercase and uppercase) with a length in the range of [12, 64].
    """
    s = ""
    for i in range(random.randint(12, 64)):
        s += random.choice(string.ascii_letters)
    return s

# %%
# Randomly generates 100 strings and then encrypts them
for i in range(100):
    print(f"Random string #{i + 1}")
    s = random_string()  # generate random string
    print(f"      Plain: {s}")  # print the string
    print(f"  Encrypted: {encrypt(s)}")  # print the encrypted string
    assert s == decrypt(
        encrypt(s)
    )  # assert that an decrypted encrypted string is the same as the original string
# Out:
# Random string #1
#       Plain: LcVKDlaHzqNEFrbK
#   Encrypted: TgKIYtsJfuBPXozI
# Random string #2
#       Plain: ZdawPTFfJTkuOsRZXEgjJJwDkIOGlFninJrGQHwjQAGcJjBBninyhjFnVKkbGxKS
#   Encrypted: FyscLRXxVRimHdOFQPevVVcYiAHEtXbabVoEUJcvUSEgVvZZbabnjvXbKIizEqID
# Random string #3
#       Plain: GPpWphIYkjxFYIuEwXqUMVaJvVMkXYPcnSOVTmRdvg
#   Encrypted: ELlCljANivqXNAmPcQuMWKsVkKWiQNLgbDHKRwOyke
# Random string #4
#       Plain: QrubLyfFRBZzFuiUtPBFOmlbu
#   Encrypted: UomzTnxXOZFfXmaMrLZXHwtzm
# Random string #5
#       Plain: wtishzaPaZBHyaHhEyEGKTRhmDlBsXAmuEidPGAFkxrqKBbXfiBvcnZSWfjK
#   Encrypted: cradjfsLsFZJnsJjPnPEIROjwYtZdQSwmPayLESXiqouIZzQxaZkgbFDCxvI
# Random string #6
#       Plain: ZspZWQGJHRuozjxoD
#   Encrypted: FdlFCUEVJOmhfvqhY
# Random string #7
#       Plain: PjuFXaIpkBoTikEzDvRLoBdMPCZkgNcfjthHwW
# Random string #55
#       Plain: QLelBhARybjHUqpSnkyffTpTKTZBOSTRHiMuquHhxSF
#   Encrypted: UTptZjSOnzvJMulDbinxxRlRIRFZHDROJaWmumJjqDX
# Random string #56
#       Plain: rWAYxBoBvthYEgMKVGdhgxyXNKKIxkxxiOnNDhsyFFn
#   Encrypted: oCSNqZhZkrjNPeWIKEyjeqnQBIIAqiqqaHbBYjdnXXb
# Random string #57
#       Plain: gQoLKtTNyDKBAESUEYkKgwSgxXAqkmW
#   Encrypted: eUhTIrRBnYIZSPDMPNiIecDeqQSuiwC
# Random string #58
#       Plain: hSAZolXsFkaKNjVXksHRMVujCiMQgzZRVGXZWkDoPwERim
#   Encrypted: jDSFhtQdXisIBvKQidJOWKmvGaWUefFOKEQFCiYhLcPOaw
# Random string #59
#       Plain: dQontQKGpnZzbQJZoyTBYEeCFZEfZTAFCNnMzsm
#   Encrypted: yUhbrUIElbFfzUVFhnRZNPpGXFPxFRSXGBbWfdw
# Random string #60
#       Plain: KTwLKIgvZcQLSXxlusxl
#   Encrypted: IRcTIAekFgUTDQqtmdqt
# Random string #61
#       Plain: SmfsYoNPsZUUpfgdXSYkcOwgIGrudKVliGdlpilMAcAlk
#   Encrypted: DwxdNhBLdFMMlxeyQDNigHceAEomyIKtaEytlatWSgSti
# Random string #62
#       Plain: SGZWyeUbHCxgSzOxUOS
#   Encrypted: DEFCnpMzJGqeDfHqMHD
# Random string #63
#       Plain: tceWbTcrvnsXiahoQJFRKggQJ
#   Encrypted: rgpCzRgokbdQasjhUVXOIeeUV
# Random string #64
#       Plain: EyotKIgECKnofUZOfNBCPrzkLFZIbusLsbtx
#   Encrypted: PnhrIAePGIbhxMFHxBZGLofiTXFAzmdTdzrq
# Random string #65
#       Plain: TTZcUpNcuejgYPgSBtNXdDqCsJgrIyCsoPuHTLYdAfvSJtqCGHdcLnIJnt
#   Encrypted: RRFgMlBgmpveNLeDZrBQyYuGdVeoAnGdhLmJRTNySxkDVruGEJygTbAVbr
# Random string #66
#       Plain: CYMaYJrwPiwifpKegFgqkOIEapt
#   Encrypted: GNWsNVocLacaxlIpeXeuiHAPslr
# Random string #67
#       Plain: gsquCAwWxJMRDNjNrWwQIYEAcUnYZioLqTTGUDhBAjApMcv
#   Encrypted: edumGScCqVWOYBvBoCcUANPSgMbNFahTuRREMYjZSvSlWgk
# Random string #68
#       Plain: AMtFgXfytQcRNyiJSfMdtdbYBSgtfsHawNfaHMhQqYrhYjFXVpfSKjDDeafc
#   Encrypted: SWrXeQxnrUgOBnaVDxWyryzNZDerxdJscBxsJWjUuNojNvXQKlxDIvYYpsxg
# Random string #69
#       Plain: gZgxAlAQcznXBJoAEwoMskPrlqNeTUOTCdjICLOWqKNQZyZRgiYNNXNaZOu
#   Encrypted: eFeqStSUgfbQZVhSPchWdiLotuBpRMHRGyvAGTHCuIBUFnFOeaNBBQBsFHm
# Random string #70
#       Plain: WIyEWCBGgXjOAYyNXuVORkOokhRoVyNbKCImdLX
#   Encrypted: CAnPCGZEeQvHSNnBQmKHOiHhijOhKnBzIGAwyTQ
# Random string #71
#       Plain: nUGJBVEiBWLTucqQWkRsVNSAYtFOuOWBWTsVjuyMHlFyuQVDlMuz
#   Encrypted: bMEVZKPaZCTRmguUCiOdKBDSNrXHmHCZCRdKvmnWJtXnmUKYtWmf
# Random string #72
#       Plain: IiPQUyPocQUzcQusBpTEBydJQBIAxBdZpvRfyW
#   Encrypted: AaLUMnLhgUMfgUmdZlRPZnyVUZASqZyFlkOxnC
# Random string #73
#       Plain: nMIvCXqjuRdrElaWNNj
#   Encrypted: bWAkGQuvmOyoPtsCBBv
# Random string #74
#       Plain: jELCdDRgoBAYUhfvjnPWxeDbCBDrZGHolmcpooiLToZypIyhjKlKxgvmNATaDsxQ
#   Encrypted: vPTGyYOehZSNMjxkvbLCqpYzGZYoFEJhtwglhhaTRhFnlAnjvItIqekwBSRsYdqU
# Random string #75
#       Plain: OUMNLphYKYvoT
#   Encrypted: HMWBTljNINkhR
# Random string #76
#       Plain: UhQcSFnYEmnzSGFSMOOwFOlcpEJMtoMaPNZVkctOhieUYYnlbb
#   Encrypted: MjUgDXbNPwbfDEXDWHHcXHtglPVWrhWsLBFKigrHjapMNNbtzz
# Random string #77
#       Plain: LaowjlsdNGpLRMaSALAxjYIHTrvrHTNeqwDGJdP
#   Encrypted: TshcvtdyBElTOWsDSTSqvNAJRokoJRBpucYEVyL
# Random string #78
#       Plain: LySKgLwcxNPMRGCqQeAOIiemASuTdOAmredEX
#   Encrypted: TnDIeTcgqBLWOEGuUpSHAapwSDmRyHSwopyPQ
# Random string #79
#       Plain: oWxeNKWdBPMUoLPVgV
#   Encrypted: hCqpBICyZLWMhTLKeK
# Random string #80
#       Plain: ychBEmvPaFUirjdSdmAcAsh
#   Encrypted: ngjZPwkLsXMaovyDywSgSdj
# Random string #81
#       Plain: oZCWehoRPsusCYREOaOwVGLfYmycnKJoABYvIrGGPRQkoEnpYUFXe
#   Encrypted: hFGCpjhOLdmdGNOPHsHcKETxNwngbIVhSZNkAoEELOUihPblNMXQp
# Random string #82
#       Plain: wfcLlumQExcQzQPjXOXzNVUdHGqNedLrtaKlOKpVXKNEcCSGvWLcaQllkCgc
#   Encrypted: cxgTtmwUPqgUfULvQHQfBKMyJEuBpyTorsItHIlKQIBPgGDEkCTgsUttiGeg
# Random string #83
#       Plain: USJmQPzomUIn
#   Encrypted: MDVwULfhwMAb
# Random string #84
#       Plain: tSCtoNpWgFZVBuUkpolYFjgYIDMAkunKGQpCcgCGUmHlIEtkgzEnmvEwpH
#   Encrypted: rDGrhBlCeXFKZmMilhtNXveNAYWSimbIEUlGgeGEMwJtAPriefPbwkPclJ
# Random string #85
#       Plain: NHCEaOhVQbIgRsbqGqPLNRbGeJPrCofDAbbu
#   Encrypted: BJGPsHjKUzAeOdzuEuLTBOzEpVLoGhxYSzzm
# Random string #86
#       Plain: NSdDfFYqmcROOCFTPyV
#   Encrypted: BDyYxXNuwgOHHGXRLnK
# Random string #87
#       Plain: RxrSdGqMcavQSsyNayjebQchhrDaDfEotynfaNzRLZifasbNKUKU
#   Encrypted: OqoDyEuWgskUDdnBsnvpzUgjjoYsYxPhrnbxsBfOTFaxsdzBIMIM
# Random string #88
#       Plain: oOPDFIxXOXrccmIqOjFOBmvTmYMQkMaMNLpBZvCcwKUKabbDMOglabgkbt
#   Encrypted: hHLYXAqQHQoggwAuHvXHZwkRwNWUiWsWBTlZFkGgcIMIszzYWHetszeizr
# Random string #89
#       Plain: QGPqzmfomvtnSbCIlFeuUpLSllQtxFvRfgHupdlfwmSAXPCbbIkJTyTdbRtGKD
#   Encrypted: UELufwxhwkrbDzGAtXpmMlTDttUrqXkOxeJmlytxcwDSQLGzzAiVRnRyzOrEIY
# Random string #90
#       Plain: fpLCzdhivSfYcQNrIledzoyEbHpiSBNHWRCdvuwqLpXFXEAKgV
#   Encrypted: xlTGfyjakDxNgUBoAtpyfhnPzJlaDZBJCOGykmcuTlQXQPSIeK
# Random string #91
#       Plain: DUkpMaLuJrGZvvwUnKZfpZztVelmsPFTobRvcBXpLJDlKduoJlQv
#   Encrypted: YMilWsTmVoEFkkcMbIFxlFfrKptwdLXRhzOkgZQlTVYtIymhVtUk
# Random string #92
#       Plain: BEocHpNGiXkWjSsoVricIddcNdqhDYqMvLTRFtKPqEGtCjFfShMbkZeeCHB
#   Encrypted: ZPhgJlBEaQiCvDdhKoagAyygByujYNuWkTROXrILuPErGvXxDjWziFppGJZ
# Random string #93
#       Plain: AzvapniggCyQFFpDwImbZED
#   Encrypted: SfkslbaeeGnUXXlYcAwzFPY
# Random string #94
#       Plain: EWuwXSeNZPrSAVCiRnMNvHlpKNJbNOZMdPpdyeIwMmJJBbCcOvdaxzxMXLCJPq
#   Encrypted: PCmcQDpBFLoDSKGaObWBkJtlIBVzBHFWyLlynpAcWwVVZzGgHkysqfqWQTGVLu
# Random string #95
#       Plain: DBhwlBlSFtBLXjYsAUFYWxLFdtzDGBZzTuYMGucypzlQuWJhJuilbncJG
#   Encrypted: YZjctZtDXrZTQvNdSMXNCqTXyrfYEZFfRmNWEmgnlftUmCVjVmatzbgVE
# Random string #96
#       Plain: HqkIIDdxDbvOQEO
#   Encrypted: JuiAAYyqYzkHUPH
# Random string #97
#       Plain: kEdWfjMRUMfvlwtBqrsaBfBiedXbi
#   Encrypted: iPyCxvWOMWxktcrZuodsZxZapyQza
# Random string #98
#       Plain: soShHJvJMUlzEiLXaMHrbvkjvC
#   Encrypted: dhDjJVkVWMtfPaTQsWJozkivkG
# Random string #99
#       Plain: ITXzmOamEezQVxyVinuKumCfNxVs
#   Encrypted: ARQfwHswPpfUKqnKabmImwGxBqKd
# Random string #100
#       Plain: sfalVBJSmNYdMIrlXBSsePjDzPzFBHaeXWoZmkdc
#   Encrypted: dxstKZVDwBNyWAotQZDdpLvYfLfXZJspQChFwiyg
